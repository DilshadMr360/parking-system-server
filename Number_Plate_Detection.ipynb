# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 4.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import ultralytics

# %%
from ultralytics import YOLO

# %%
train_path_img = "/content/drive/MyDrive/Final/NumberPlateDetection/train/images"
train_path_label = "/content/drive/MyDrive/Final/NumberPlateDetection/train/labels"
val_path_img = "/content/drive/MyDrive/Final/NumberPlateDetection/val/images"
val_path_label = "/content/drive/MyDrive/Final/NumberPlateDetection/val/labels"

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/Final/NumberPlateDetection/Number_Plate_Detect.yaml epochs=100 imgsz=640 batch=8 project=/content/drive/MyDrive name=number_plate
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 160MB/s]
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/number_plate/weights/best.pt conf=0.25 source=/content/122.mp4
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/1800) /content/122.mp4: 384x640 (no detections), 161.2ms
# video 1/1 (frame 2/1800) /content/122.mp4: 384x640 (no detections), 12.4ms
# video 1/1 (frame 3/1800) /content/122.mp4: 384x640 1 Number_Plate_Detected, 15.5ms
# video 1/1 (frame 4/1800) /content/122.mp4: 384x640 1 Number_Plate_Detected, 10.8ms
# video 1/1 (frame 5/1800) /content/122.mp4: 384x640 1 Number_Plate_Detected, 10.8ms
# video 1/1 (frame 6/1800) /content/122.mp4: 384x640 1 Number_Plate_Detected, 10.8ms
# video 1/1 (frame 7/1800) /content/122.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (frame 8/1800) /content/122.mp4: 384x640 1 Number_Plate_Detected, 11.2ms
# video 1/1 (frame 9/1800) /content/122.mp4: 384x640 1 Number_Plate_Detected, 10.7ms
# ...
